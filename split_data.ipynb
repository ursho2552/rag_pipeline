# %%
import pandas as pd

# %%
directory = "/Users/urshofmannelizondo/Documents/PhD/local_rag/test_data/"
df = pd.read_csv(f"{directory}metadata_V14.csv")

# %%
df_with_depth = df[df['depth'].isna()==False]
df_without_depth = df[(df['depth'].isna()==True)*(df['depth_original'].isna()==False)]
df_without_depth['depth'] = 'missing'

df_with_depth.to_csv(f'{directory}metadata_V14_with_depth.csv')
df_without_depth.to_csv(f'{directory}metadata_V14_without_depth.csv')
# Out:
# /var/folders/bv/kclw0qy52ksc563qxtd7lg480000gp/T/ipykernel_28236/3629375938.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_depth['depth'] = 'missing'

# %%
df_without_depth
# Out:
#           biosample                 sample    ...1   dataset  \
# 4507   SAMEA7392424  KOPF15-1_SAMEA7392424  4309.0  KOPF15-1
# 4514   SAMEA7392433  KOPF15-1_SAMEA7392433  4316.0  KOPF15-1
# 4528   SAMEA7392449  KOPF15-1_SAMEA7392449  4330.0  KOPF15-1
# 4575   SAMEA7422962  KOPF15-1_SAMEA7422962  4377.0  KOPF15-1
# 4615   SAMEA7723412  SHAF22-1_SAMEA7723412  7788.0  SHAF22-1
# ...             ...                    ...     ...       ...
# 11774  SAMN22234007  BRAM21-1_SAMN22234007  1853.0  BRAM21-1
# 11775  SAMN22234008  BRAM21-1_SAMN22234008  1854.0  BRAM21-1
# 11776  SAMN22234009  BRAM21-1_SAMN22234009  1855.0  BRAM21-1
# 11777  SAMN22234010  BRAM21-1_SAMN22234010  1856.0  BRAM21-1
# 11778  SAMN22234011  BRAM21-1_SAMN22234011  1857.0  BRAM21-1
#
#                             bioproject  \
# 4507   PRJEB8682,PRJEB40760,PRJEB40764
# 4514   PRJEB8682,PRJEB40760,PRJEB40764
# 4528   PRJEB8682,PRJEB40760,PRJEB40764
# 4575   PRJEB8682,PRJEB40760,PRJEB40764
# ...
