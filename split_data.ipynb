# %%
import pandas as pd

# %%
directory = "/nfs/sea/work/deriksson/Projects/PhD_Objective_2/Data/Jonas_Richter/Metadaten/"
df = pd.read_csv(f"{directory}metadata_V14.csv")

# %%
directory_out = '/net/sea/work/ursho/PhD/Projects/rag_pipeline/test_data/'
df_with_depth = df[df['depth'].isna()==False]
df_without_depth = df[(df['depth'].isna()==True)*(df['depth_original'].isna()==False)]
df_without_depth = df[df['depth'].isna()==True]

df_without_depth['depth'] = 'missing'

df_with_depth.to_csv(f'{directory_out}metadata_V14_with_depth.csv')
df_without_depth.to_csv(f'{directory_out}metadata_V14_without_depth_full.csv')
# Out:
# /home/ursho/anaconda3/envs/py3_parcels/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_without_depth
# Out:
#             biosample                   sample     ...1   dataset  \
# 0      Gp0561256-S001  WIND23-1_Gp0561256-S001  11551.0  WIND23-1
# 1      Gp0561257-S001  WIND23-1_Gp0561257-S001  11552.0  WIND23-1
# 2      Gp0561258-S001  WIND23-1_Gp0561258-S001  11553.0  WIND23-1
# 3      Gp0561259-S001  WIND23-1_Gp0561259-S001  11554.0  WIND23-1
# 4      Gp0561260-S001  WIND23-1_Gp0561260-S001  11555.0  WIND23-1
# ...               ...                      ...      ...       ...
# 12209    SAMN27365859    TAOJ22-1_SAMN27365859   8361.0  TAOJ22-1
# 12210    SAMN27365860    TAOJ22-1_SAMN27365860   8362.0  TAOJ22-1
# 12211    SAMN27365861    TAOJ22-1_SAMN27365861   8363.0  TAOJ22-1
# 12212    SAMN27365862    TAOJ22-1_SAMN27365862   8364.0  TAOJ22-1
# 12213    SAMN27365863    TAOJ22-1_SAMN27365863   8365.0  TAOJ22-1
#
#                   bioproject sample_description         geo_loc_name  \
# 0      jgi-TheIntArctiOcean/      not specified  sea_ice_interface_1
# ...
